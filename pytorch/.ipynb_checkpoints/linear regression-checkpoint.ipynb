# %%
# %matplotlib inline
import random
import torch
from d2l import torch as d2l

# %%
def synthetic_data(w, b, num_examples):
    X = torch.normal(0,1,(num_examples,len(w)))
    y = torch.matmul(X,w) + b
    y += torch.normal(0,0.01,y.shape)
    return X,y.reshape((-1,1))

true_w = torch.tensor([2,-3.4])
true_b = 4.2
features, labels = synthetic_data(true_w,true_b,1000)
labels.shape
# Out:
# torch.Size([1000, 1])

# %%
d2l.set_figsize()
d2l.plt.scatter(features[:, 1].detach().numpy(), labels.detach().numpy(), 1);
print(features[0:10])
# Out:
# tensor([[-0.2675,  0.5668],
#         [ 0.5632,  0.9973],
#         [-0.1064,  1.2065],
#         [ 1.1193, -0.1160],
#         [ 0.5536,  1.4274],
#         [ 0.3323, -1.2821],
#         [ 1.6427,  1.2543],
#         [-1.1133,  0.5773],
#         [-0.2754, -1.5241],
#         [ 1.0359,  2.6837]])

# %%
def data_iter(batch_size, features, labels):
    num_examples = len(features)
    indices = list(range(num_examples))
    random.shuffle(indices)
    for i in range(0,num_examples,batch_size):
        batch_indice = indices[i:min(i+batch_size,num_examples)]
        #print(batch_indice)
        yield features[batch_indice],labels[batch_indice]

# %%
batch_size = 10

for X, y in data_iter(batch_size, features, labels):
    print(X, '\n', y)
    print(type(data_iter(batch_size, features, labels)))
    break
# Out:
# tensor([[-0.7986,  0.8011],
#         [-0.4655,  0.0953],
#         [ 0.6313,  0.4482],
#         [ 0.7927,  0.8755],
#         [-0.7440, -1.0281],
#         [ 0.5937,  0.1807],
#         [-0.5146,  1.9860],
#         [ 0.7786, -0.1076],
#         [-0.9788, -1.6768],
#         [-0.6150,  0.8603]])
#  tensor([[-0.1076],
#         [ 2.9470],
#         [ 3.9517],
#         [ 2.7765],
#         [ 6.2072],
#         [ 4.7797],
#         [-3.5666],
#         [ 6.1139],
#         [ 7.9334],
#         [ 0.0551]])
# <class 'generator'>

# %%
w = torch.normal(0, 0.01, size=(2,1), requires_grad=True)
b = torch.zeros(1, requires_grad=True)

# %%
def linreg(X,w,b):
    return torch.matmul(X,w)+b

# %%
def square_loss(y_hat, y):
    return (y.reshape(y_hat.shape) - y_hat) ** 2 / 2

# %%
def sgd(params, lr, batch_size):
    with torch.no_grad():
        for param in params:
            param -= lr * param.grad / batch_size
            param.grad.zero_()

# %%
lr = 0.03
num_epochs = 3
net = linreg
loss = square_loss
for epoch in range(num_epochs):
    for X,y in data_iter(batch_size, features, labels):
        l = loss(net(X,w,b),y)
        l.sum().backward()
        sgd([w,b],lr,batch_size)
        #break
    with torch.no_grad():
        l = loss(net(features,w,b),labels)
        print(f"Epoch:{epoch+1}, Loss = {l.mean()}")
        print(w,b)

print(w,b)
# Out:
# Epoch:1, Loss = 0.03821218013763428
# tensor([[ 1.8953],
#         [-3.2660]], requires_grad=True) tensor([3.9789], requires_grad=True)
# Epoch:2, Loss = 0.00014849801664240658
# tensor([[ 1.9940],
#         [-3.3947]], requires_grad=True) tensor([4.1876], requires_grad=True)
# Epoch:3, Loss = 5.451642573461868e-05
# tensor([[ 1.9995],
#         [-3.3996]], requires_grad=True) tensor([4.1986], requires_grad=True)
# tensor([[ 1.9995],
#         [-3.3996]], requires_grad=True) tensor([4.1986], requires_grad=True)

# %%
print(f'w的估计误差: {true_w - w.reshape(true_w.shape)}')
print(f'b的估计误差: {true_b - b}')
# Out:
# w的估计误差: tensor([ 0.0005, -0.0004], grad_fn=<SubBackward0>)
# b的估计误差: tensor([0.0014], grad_fn=<RsubBackward1>)
